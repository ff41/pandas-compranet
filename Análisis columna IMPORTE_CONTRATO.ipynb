# %% [markdown]
# # Análisis columna IMPORTE_CONTRATO
# Las banderas 23 y 24 contemplan esta columna.
#
# La bandera 23 contempla buscar un número que permita identificar importes de contratos abnormalmente altos. Para lo anterior se propone que la bandera se levante si el monto del contrato es por arriba del promedio de todos los importes de contrato de compranet.
#
# La bandera 24 se levanta cuando el importe del contrato es 0.0

# %%
import pandas as pd

# %%
df = pd.read_csv('Documentos/compranet.csv')
# Out:
# /home/felix/miniconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (5,27,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pd.read_csv('Documentos/compranet.csv')
# Out:
#                                                    ANUNCIO  \
# 0        https://compranet.funcionpublica.gob.mx/esop/g...
# 1        https://compranet.funcionpublica.gob.mx/esop/g...
# 2        https://compranet.funcionpublica.gob.mx/esop/g...
# 3        https://compranet.funcionpublica.gob.mx/esop/g...
# 4        https://compranet.funcionpublica.gob.mx/esop/g...
# 5        https://compranet.funcionpublica.gob.mx/esop/g...
# 6        https://compranet.funcionpublica.gob.mx/esop/g...
# 7        https://compranet.funcionpublica.gob.mx/esop/g...
# 8        https://compranet.funcionpublica.gob.mx/esop/g...
# 9        https://compranet.funcionpublica.gob.mx/esop/g...
# 10       https://compranet.funcionpublica.gob.mx/esop/g...
# 11       https://compranet.funcionpublica.gob.mx/esop/g...
# 12       https://compranet.funcionpublica.gob.mx/esop/g...
# 13       https://compranet.funcionpublica.gob.mx/esop/g...
# 14       https://compranet.funcionpublica.gob.mx/esop/g...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1054494 entries, 0 to 1054493
# Data columns (total 45 columns):
# ANUNCIO                         1043433 non-null object
# APORTACION_FEDERAL              50990 non-null float64
# ARCHIVADO                       1054494 non-null object
# CARACTER                        993162 non-null object
# CLAVEUC                         1054494 non-null object
# CLAVE_CARTERA_SHCP              5294 non-null object
# CLAVE_PROGRAMA                  35072 non-null object
# CODIGO_CONTRATO                 1054494 non-null float64
# CODIGO_EXPEDIENTE               1054494 non-null float64
# COMPRA_CONSOLIDADA              1047673 non-null float64
# CONTRATO_MARCO                  672275 non-null float64
# CONVENIO_MODIFICATORIO          1054162 non-null float64
# CUENTA_ADMINISTRADA_POR         1054494 non-null object
# C_EXTERNO                       67829 non-null float64
# DEPENDENCIA                     1054494 non-null object
# ...

# %%
df.groupby("TITULO_CONTRATO").IMPORTE_CONTRATO.sum().reset_index().sort_values("IMPORTE_CONTRATO", ascending=False)
# Out:
#                                           TITULO_CONTRATO  IMPORTE_CONTRATO
# 418001                                       MEDICAMENTOS      1.031430e+11
# 216887  CONSTRUCCION DEL EDIFICIO TERMINAL DEL NUEVO A...      8.482838e+10
# 433646                                       Medicamentos      4.621078e+10
# 260312  Carbón Mineral Termico No Coquizable Subbitumi...      2.373840e+10
# 240862  CONTRATO DE OBRA PUBLICA A PRECIOS UNITARIOS Y...      2.331335e+10
# 243072  CONTRATO DE SERVICIOS PROFESIONALES DE TERCERO...      1.265421e+10
# 652815  Suministro, Instalación y Puesta en Marcha de ...      1.169836e+10
# 582581  SERVICIO DE VIGILANCIA  DEL PARQUE FUNDIDORA, ...      1.109352e+10
# 229878  CONTRATACIÓN DE TERCEROS ESPECIALIZADOS (ABOGA...      9.304559e+09
# 419046                              MEDIDORES DE POTENCIA      9.103610e+09
# 662282  TRABAJOS DE CONSTRUCCIÓN Y OBRAS COMPLEMENTARI...      8.988170e+09
# ...

# %% [markdown]
# Podemos observar que hay varios contratos que tienen 0.0 de valor.

# %%
df.IMPORTE_CONTRATO.mean()
# Out:
# 2625874.0897992784

# %% [markdown]
# Podemos utilizar este número para determinar el valor que levantaría la bandera 23 ÁMBAR.

# %%
df.IMPORTE_CONTRATO.describe()
# Out:
# count    1.054494e+06
# mean     2.625874e+06
# std      9.913038e+07
# min      0.000000e+00
# 25%      4.116000e+04
# 50%      1.384615e+05
# 75%      5.954897e+05
# max      8.482838e+10
# Name: IMPORTE_CONTRATO, dtype: float64

# %% [markdown]
# También podemos usar desviación estándar (std)

# %% [markdown]
# Se propone excluir del promedio de la columna IMPORTE_CONTRATO a los contratos con valor "0.0"

# %%
flag23 = df[df.IMPORTE_CONTRATO > 0.0]

# %%
flag23.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1054141 entries, 0 to 1054493
# Data columns (total 45 columns):
# ANUNCIO                         1043094 non-null object
# APORTACION_FEDERAL              50984 non-null float64
# ARCHIVADO                       1054141 non-null object
# CARACTER                        992834 non-null object
# CLAVEUC                         1054141 non-null object
# CLAVE_CARTERA_SHCP              5289 non-null object
# CLAVE_PROGRAMA                  35063 non-null object
# CODIGO_CONTRATO                 1054141 non-null float64
# CODIGO_EXPEDIENTE               1054141 non-null float64
# COMPRA_CONSOLIDADA              1047321 non-null float64
# CONTRATO_MARCO                  672024 non-null float64
# CONVENIO_MODIFICATORIO          1053809 non-null float64
# CUENTA_ADMINISTRADA_POR         1054141 non-null object
# C_EXTERNO                       67802 non-null float64
# DEPENDENCIA                     1054141 non-null object
# ...

# %%
flag23.sort_values("IMPORTE_CONTRATO")

# %%
flag23.IMPORTE_CONTRATO.min()
