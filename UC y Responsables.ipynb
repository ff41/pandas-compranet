# %% [markdown]
# # Análisis Responsables y Unidades Compradoras
#
# Este notebook es para documentar el análisis de que una sola persona es responsable de múltiples unidades compradoras.

# %%
import pandas as pd

# %% [markdown]
# Voy a importar el directorio de Unidades Compradoras (UC) en formato csv que se encuentra en el sitio: "https://sites.google.com/site/cnetuc/directorio"

# %%
uc = pd.read_csv('Documentos/Pouvoir/QQW/2017/banderas/UC_170612072400.csv')

# %%
uc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5230 entries, 0 to 5229
# Data columns (total 18 columns):
# ID_DEP_ENT              5230 non-null int64
# SIGLAS                  5230 non-null object
# DEPENDENCIA_ENTIDAD     5230 non-null object
# RAMO                    5230 non-null int64
# CLAVE_CNET30            5230 non-null object
# CLAVE_UC                5230 non-null object
# NOMBRE_UC               5230 non-null object
# RFC                     5229 non-null object
# ESTADO                  5230 non-null object
# DELEGACION_MUNICIPIO    5230 non-null object
# TELEFONO_UC             5230 non-null object
# DIRECCION               5230 non-null object
# CP                      5229 non-null object
# PAGINA_WEB              4859 non-null object
# TIPO                    5230 non-null object
# ZONA_HORARIA            5230 non-null object
# RESPONSABLE             5230 non-null object
# PUESTO                  5198 non-null object
# dtypes: int64(2), object(16)
# memory usage: 735.5+ KB

# %%
uc.RESPONSABLE.value_counts()
# Out:
# AVILA CECEÑA SERGIO                        4
# Rosique Valenzuela Maria Estela            4
# Vázquez Sastré Angel                       3
# Aguilar Rojo Gustavo                       3
# Perales Vilchis Francisca Guadalupe        3
# AQUINO AVENDAÑO SERGIO RAUL                3
# Abreu Field Manuel Guillermo               3
# Díaz Gómez Manuel                          3
# González Betanzos Josimar Carlos           3
# Lorences Villanueva Blanca Estela          3
# Tabe Morales Christiane                    3
# Bojorquez Manzo Rafael                     3
# Rodríguez Haro Eduardo                     2
# Navarro Moreno Jorge Luis                  2
# OCHOA VALENCIA ERICK ALEXIS                2
# Verduzco Padilla Fernando Ernesto          2
# Cortés Montalvo José Patricio              2
# Ibarra Guerra Jorge                        2
# GOMEZ CARDENAS MOISES                      2
# Hernández Ortiz Bruno                      2
# Soto Cortez Luis Alfonso                   2
# Bustos Guerrero Miguel Ángel               2
# MENDEZ AVALOS EDITH ACASIA                 2
# Hernández Galván Guillermina               2
# Cuevas López Renato Carlos                 2
# Ortega Serventi Fernando                   2
# Rodríguez Silva Víctor Manuel              2
# Tadeo Nava Raul                            2
# Lobo Crenier Jorge                         2
# Cisneros González Abel                     2
#                                           ..
# Bareño Ramírez Francisco Javier            1
# Garrido Pacheco Bianca Heidi               1
# Ramos Jimenez Claudia Adriana Alexandra    1
# LEAÑOS RODRIGUEZ LUZ ADRIANA               1
# Cornejo Jimenez Ernesto                    1
# Aguirre  Valencia Raúl Salvador            1
# SANTIAGO CURIEL LUIS FELIPE                1
# Rojas Soto María Dolores                   1
# BECERRA CONTRERAS CARLOS MARCELO           1
# Palma Carro Arturo Jesus                   1
# FLORES GUZMAS JOSE ARTURO                  1
# Leal Quistian José Hilario                 1
# MORALES VALDÉS NADIA                       1
# DIAS GONZALEZ GUSTAVO                      1
# Torres Sanchez Fernando Daniel             1
# LIAHUT ATZIN CARLOS EDUARDO                1
# Velasco Loza Vicente Indalecio             1
# Becheret Ruíz José Ramón                   1
# Jiménez Rojo Daniel Rolando                1
# Rosas Mejia Juan Antonio                   1
# BARRERA  HUERTA MIGUEL ANGEL               1
# RUIZ ANDRADE JAVIER                        1
# PEREZ ESQUIVEL VICENTE                     1
# Gelover  Pérez Edgardo Vito                1
# MENDEZ SALGADO GUILLERMO                   1
# Merida de la Cruz Humberto                 1
# CADENA  ARMENTA JOSE                       1
# Leyva Mercado Teresa Irasema               1
# ZARATE ROSALES RENAN                       1
# Aguilar  Esparza Sergio Marcelo            1
# Name: RESPONSABLE, Length: 5126, dtype: int64

# %% [markdown]
# A partir de estos resultados queremos analizar si las UC en la que los responsables se repiten más de una vez en efecto son distintas.

# %%
uc[uc.RESPONSABLE == "AVILA CECEÑA SERGIO"].groupby("NOMBRE_UC").count()
# Out:
#                                                     ID_DEP_ENT  SIGLAS  \
# NOMBRE_UC
# SON-Secretaria de Agricultura, Ganadería, Recur...           1       1
# SON-Secretaria de Agricultura, Ganadería, Recur...           1       1
# SON-Secretaria de Agricultura, Ganadería, Recur...           1       1
# SON-Secretaria de Agricultura, Ganadería, Recur...           1       1
#
#                                                     DEPENDENCIA_ENTIDAD  RAMO  \
# NOMBRE_UC
# SON-Secretaria de Agricultura, Ganadería, Recur...                    1     1
# SON-Secretaria de Agricultura, Ganadería, Recur...                    1     1
# SON-Secretaria de Agricultura, Ganadería, Recur...                    1     1
# SON-Secretaria de Agricultura, Ganadería, Recur...                    1     1
#
#                                                     CLAVE_CNET30  CLAVE_UC  \
# NOMBRE_UC
# SON-Secretaria de Agricultura, Ganadería, Recur...             1         1
# SON-Secretaria de Agricultura, Ganadería, Recur...             1         1
# SON-Secretaria de Agricultura, Ganadería, Recur...             1         1
# SON-Secretaria de Agricultura, Ganadería, Recur...             1         1
#
#                                                     RFC  ESTADO  \
# NOMBRE_UC
# SON-Secretaria de Agricultura, Ganadería, Recur...    1       1
# SON-Secretaria de Agricultura, Ganadería, Recur...    1       1
# SON-Secretaria de Agricultura, Ganadería, Recur...    1       1
# SON-Secretaria de Agricultura, Ganadería, Recur...    1       1
#
#                                                     DELEGACION_MUNICIPIO  \
# NOMBRE_UC
# SON-Secretaria de Agricultura, Ganadería, Recur...                     1
# SON-Secretaria de Agricultura, Ganadería, Recur...                     1
# SON-Secretaria de Agricultura, Ganadería, Recur...                     1
# SON-Secretaria de Agricultura, Ganadería, Recur...                     1
#
#                                                     TELEFONO_UC  DIRECCION  \
# NOMBRE_UC
# SON-Secretaria de Agricultura, Ganadería, Recur...            1          1
# SON-Secretaria de Agricultura, Ganadería, Recur...            1          1
# SON-Secretaria de Agricultura, Ganadería, Recur...            1          1
# SON-Secretaria de Agricultura, Ganadería, Recur...            1          1
#
#                                                     CP  PAGINA_WEB  TIPO  \
# NOMBRE_UC
# SON-Secretaria de Agricultura, Ganadería, Recur...   1           1     1
# SON-Secretaria de Agricultura, Ganadería, Recur...   1           1     1
# SON-Secretaria de Agricultura, Ganadería, Recur...   1           1     1
# SON-Secretaria de Agricultura, Ganadería, Recur...   1           1     1
#
#                                                     ZONA_HORARIA  RESPONSABLE  \
# NOMBRE_UC
# SON-Secretaria de Agricultura, Ganadería, Recur...             1            1
# SON-Secretaria de Agricultura, Ganadería, Recur...             1            1
# SON-Secretaria de Agricultura, Ganadería, Recur...             1            1
# SON-Secretaria de Agricultura, Ganadería, Recur...             1            1
#
#                                                     PUESTO
# NOMBRE_UC
# SON-Secretaria de Agricultura, Ganadería, Recur...       1
# SON-Secretaria de Agricultura, Ganadería, Recur...       1
# SON-Secretaria de Agricultura, Ganadería, Recur...       1
# SON-Secretaria de Agricultura, Ganadería, Recur...       1

# %% [markdown]
# Como podemos leer en la columna "NOMBRE_UC" existen dos UC con el mismo nombre pero los cuatro nombres tienen un nombre al final. Podemos comprobar si estas UC tienen una clave única distinta en la columna CLAVE_UC.

# %%
uc[uc.RESPONSABLE == "AVILA CECEÑA SERGIO"].groupby("CLAVE_UC").count()
# Out:
#            ID_DEP_ENT  SIGLAS  DEPENDENCIA_ENTIDAD  RAMO  CLAVE_CNET30  \
# CLAVE_UC
# 926008990           1       1                    1     1             1
# 926008991           1       1                    1     1             1
# 926008998           1       1                    1     1             1
# 926008999           1       1                    1     1             1
#
#            NOMBRE_UC  RFC  ESTADO  DELEGACION_MUNICIPIO  TELEFONO_UC  \
# CLAVE_UC
# 926008990          1    1       1                     1            1
# 926008991          1    1       1                     1            1
# 926008998          1    1       1                     1            1
# 926008999          1    1       1                     1            1
#
#            DIRECCION  CP  PAGINA_WEB  TIPO  ZONA_HORARIA  RESPONSABLE  PUESTO
# CLAVE_UC
# 926008990          1   1           1     1             1            1       1
# 926008991          1   1           1     1             1            1       1
# 926008998          1   1           1     1             1            1       1
# 926008999          1   1           1     1             1            1       1

# %% [markdown]
# En efecto, las cuatro UC están registradas como unidades distintas. Esto implica una bandera por cada responsable que se repita en distintas Unidades Compradoras.

# %% [markdown]
# Ahora hay que comprobar que estas UC con sus responsable aparezcan en nuestra BBDD de compranet.

# %%
cnet  = pd.read_csv('Documentos/compranet.csv')
# Out:
# /home/felix/miniconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (5,27,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
cnet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1054494 entries, 0 to 1054493
# Data columns (total 45 columns):
# ANUNCIO                         1043433 non-null object
# APORTACION_FEDERAL              50990 non-null float64
# ARCHIVADO                       1054494 non-null object
# CARACTER                        993162 non-null object
# CLAVEUC                         1054494 non-null object
# CLAVE_CARTERA_SHCP              5294 non-null object
# CLAVE_PROGRAMA                  35072 non-null object
# CODIGO_CONTRATO                 1054494 non-null float64
# CODIGO_EXPEDIENTE               1054494 non-null float64
# COMPRA_CONSOLIDADA              1047673 non-null float64
# CONTRATO_MARCO                  672275 non-null float64
# CONVENIO_MODIFICATORIO          1054162 non-null float64
# CUENTA_ADMINISTRADA_POR         1054494 non-null object
# C_EXTERNO                       67829 non-null float64
# DEPENDENCIA                     1054494 non-null object
# ESTATUS_CONTRATO                1054494 non-null object
# ESTATUS_EMPRESA                 1054494 non-null object
# ESTRATIFICACION_MPC             773298 non-null object
# ESTRATIFICACION_MUC             1047673 non-null object
# EXP_F_FALLO                     326913 non-null object
# FECHA_APERTURA_PROPOSICIONES    661159 non-null object
# FECHA_CELEBRACION               499475 non-null object
# FECHA_FIN                       1054494 non-null object
# FECHA_INICIO                    1054494 non-null object
# FOLIO_RUPC                      261745 non-null float64
# FORMA_PROCEDIMIENTO             993410 non-null object
# GOBIERNO                        1054494 non-null object
# IDENTIFICADOR_CM                2840 non-null object
# IMPORTE_CONTRATO                1054494 non-null float64
# MONEDA                          1054494 non-null object
# NOMBRE_DE_LA_UC                 1054494 non-null object
# NUMERO_PROCEDIMIENTO            1054394 non-null object
# ORGANISMO                       1414 non-null object
# PLANTILLA_EXPEDIENTE            1054492 non-null object
# PLURIANUAL                      1047673 non-null float64
# PROC_F_PUBLICACION              561131 non-null object
# PROVEEDOR_CONTRATISTA           1054494 non-null object
# RAMO                            65717 non-null float64
# RESPONSABLE                     1054494 non-null object
# SIGLAS                          1054494 non-null object
# SIGLAS_PAIS                     1054494 non-null object
# TIPO_CONTRATACION               1054494 non-null object
# TIPO_PROCEDIMIENTO              1053935 non-null object
# TITULO_CONTRATO                 1054494 non-null object
# TITULO_EXPEDIENTE               1054494 non-null object
# dtypes: float64(11), object(34)
# memory usage: 362.0+ MB

# %%
cnet[cnet.CLAVEUC == "926008990"].groupby("NOMBRE_DE_LA_UC").count()
# Out:
#                                                     ANUNCIO  \
# NOMBRE_DE_LA_UC
# SON-Secretaria de Agricultura, Ganadería, Recur...      347
#
#                                                     APORTACION_FEDERAL  \
# NOMBRE_DE_LA_UC
# SON-Secretaria de Agricultura, Ganadería, Recur...                  60
#
#                                                     ARCHIVADO  CARACTER  \
# NOMBRE_DE_LA_UC
# SON-Secretaria de Agricultura, Ganadería, Recur...        347       303
#
#                                                     CLAVEUC  \
# NOMBRE_DE_LA_UC
# SON-Secretaria de Agricultura, Ganadería, Recur...      347
#
#                                                     CLAVE_CARTERA_SHCP  \
# NOMBRE_DE_LA_UC
# SON-Secretaria de Agricultura, Ganadería, Recur...                   0
#
#                                                     CLAVE_PROGRAMA  \
# NOMBRE_DE_LA_UC
# SON-Secretaria de Agricultura, Ganadería, Recur...              61
#
#                                                     CODIGO_CONTRATO  \
# NOMBRE_DE_LA_UC
# SON-Secretaria de Agricultura, Ganadería, Recur...              347
#
#                                                     CODIGO_EXPEDIENTE  \
# NOMBRE_DE_LA_UC
# SON-Secretaria de Agricultura, Ganadería, Recur...                347
#
#                                                     COMPRA_CONSOLIDADA  \
# NOMBRE_DE_LA_UC
# SON-Secretaria de Agricultura, Ganadería, Recur...                 339
#
#                                                           ...          \
# NOMBRE_DE_LA_UC                                           ...
# SON-Secretaria de Agricultura, Ganadería, Recur...        ...
#
#                                                     PROC_F_PUBLICACION  \
# NOMBRE_DE_LA_UC
# SON-Secretaria de Agricultura, Ganadería, Recur...                 347
#
#                                                     PROVEEDOR_CONTRATISTA  \
# NOMBRE_DE_LA_UC
# SON-Secretaria de Agricultura, Ganadería, Recur...                    347
#
#                                                     RAMO  RESPONSABLE  SIGLAS  \
# NOMBRE_DE_LA_UC
# SON-Secretaria de Agricultura, Ganadería, Recur...    60          347     347
#
#                                                     SIGLAS_PAIS  \
# NOMBRE_DE_LA_UC
# SON-Secretaria de Agricultura, Ganadería, Recur...          347
#
#                                                     TIPO_CONTRATACION  \
# NOMBRE_DE_LA_UC
# SON-Secretaria de Agricultura, Ganadería, Recur...                347
#
#                                                     TIPO_PROCEDIMIENTO  \
# NOMBRE_DE_LA_UC
# SON-Secretaria de Agricultura, Ganadería, Recur...                 347
#
#                                                     TITULO_CONTRATO  \
# NOMBRE_DE_LA_UC
# SON-Secretaria de Agricultura, Ganadería, Recur...              347
#
#                                                     TITULO_EXPEDIENTE
# NOMBRE_DE_LA_UC
# SON-Secretaria de Agricultura, Ganadería, Recur...                347
#
# [1 rows x 44 columns]

# %%
cnet[cnet.CLAVEUC == "926008991"].groupby("NOMBRE_DE_LA_UC").count()
# Out:
#                                                     ANUNCIO  \
# NOMBRE_DE_LA_UC
# SON-Secretaria de Agricultura, Ganadería, Recur...       58
#
#                                                     APORTACION_FEDERAL  \
# NOMBRE_DE_LA_UC
# SON-Secretaria de Agricultura, Ganadería, Recur...                   0
#
#                                                     ARCHIVADO  CARACTER  \
# NOMBRE_DE_LA_UC
# SON-Secretaria de Agricultura, Ganadería, Recur...         60        56
#
#                                                     CLAVEUC  \
# NOMBRE_DE_LA_UC
# SON-Secretaria de Agricultura, Ganadería, Recur...       60
#
#                                                     CLAVE_CARTERA_SHCP  \
# NOMBRE_DE_LA_UC
# SON-Secretaria de Agricultura, Ganadería, Recur...                   0
#
#                                                     CLAVE_PROGRAMA  \
# NOMBRE_DE_LA_UC
# SON-Secretaria de Agricultura, Ganadería, Recur...               0
#
#                                                     CODIGO_CONTRATO  \
# NOMBRE_DE_LA_UC
# SON-Secretaria de Agricultura, Ganadería, Recur...               60
#
#                                                     CODIGO_EXPEDIENTE  \
# NOMBRE_DE_LA_UC
# SON-Secretaria de Agricultura, Ganadería, Recur...                 60
#
#                                                     COMPRA_CONSOLIDADA  \
# NOMBRE_DE_LA_UC
# SON-Secretaria de Agricultura, Ganadería, Recur...                  58
#
#                                                           ...          \
# NOMBRE_DE_LA_UC                                           ...
# SON-Secretaria de Agricultura, Ganadería, Recur...        ...
#
#                                                     PROC_F_PUBLICACION  \
# NOMBRE_DE_LA_UC
# SON-Secretaria de Agricultura, Ganadería, Recur...                  58
#
#                                                     PROVEEDOR_CONTRATISTA  \
# NOMBRE_DE_LA_UC
# SON-Secretaria de Agricultura, Ganadería, Recur...                     60
#
#                                                     RAMO  RESPONSABLE  SIGLAS  \
# NOMBRE_DE_LA_UC
# SON-Secretaria de Agricultura, Ganadería, Recur...     0           60      60
#
#                                                     SIGLAS_PAIS  \
# NOMBRE_DE_LA_UC
# SON-Secretaria de Agricultura, Ganadería, Recur...           60
#
#                                                     TIPO_CONTRATACION  \
# NOMBRE_DE_LA_UC
# SON-Secretaria de Agricultura, Ganadería, Recur...                 60
#
#                                                     TIPO_PROCEDIMIENTO  \
# NOMBRE_DE_LA_UC
# SON-Secretaria de Agricultura, Ganadería, Recur...                  60
#
#                                                     TITULO_CONTRATO  \
# NOMBRE_DE_LA_UC
# SON-Secretaria de Agricultura, Ganadería, Recur...               60
#
#                                                     TITULO_EXPEDIENTE
# NOMBRE_DE_LA_UC
# SON-Secretaria de Agricultura, Ganadería, Recur...                 60
#
# [1 rows x 44 columns]

# %%
cnet[cnet.CLAVEUC == "926008990"].groupby("RESPONSABLE").count()
# Out:
#                      ANUNCIO  APORTACION_FEDERAL  ARCHIVADO  CARACTER  \
# RESPONSABLE
# SERGIO AVILA CECEÑA      347                  60        347       303
#
#                      CLAVEUC  CLAVE_CARTERA_SHCP  CLAVE_PROGRAMA  \
# RESPONSABLE
# SERGIO AVILA CECEÑA      347                   0              61
#
#                      CODIGO_CONTRATO  CODIGO_EXPEDIENTE  COMPRA_CONSOLIDADA  \
# RESPONSABLE
# SERGIO AVILA CECEÑA              347                347                 339
#
#                            ...          PLURIANUAL  PROC_F_PUBLICACION  \
# RESPONSABLE                ...
# SERGIO AVILA CECEÑA        ...                 339                 347
#
#                      PROVEEDOR_CONTRATISTA  RAMO  SIGLAS  SIGLAS_PAIS  \
# RESPONSABLE
# SERGIO AVILA CECEÑA                    347    60     347          347
#
#                      TIPO_CONTRATACION  TIPO_PROCEDIMIENTO  TITULO_CONTRATO  \
# RESPONSABLE
# SERGIO AVILA CECEÑA                347                 347              347
#
#                      TITULO_EXPEDIENTE
# RESPONSABLE
# SERGIO AVILA CECEÑA                347
#
# [1 rows x 44 columns]

# %%
cnet[cnet.CLAVEUC == "926008991"].groupby("RESPONSABLE").count()
# Out:
#                      ANUNCIO  APORTACION_FEDERAL  ARCHIVADO  CARACTER  \
# RESPONSABLE
# SERGIO AVILA CECEÑA       58                   0         60        56
#
#                      CLAVEUC  CLAVE_CARTERA_SHCP  CLAVE_PROGRAMA  \
# RESPONSABLE
# SERGIO AVILA CECEÑA       60                   0               0
#
#                      CODIGO_CONTRATO  CODIGO_EXPEDIENTE  COMPRA_CONSOLIDADA  \
# RESPONSABLE
# SERGIO AVILA CECEÑA               60                 60                  58
#
#                            ...          PLURIANUAL  PROC_F_PUBLICACION  \
# RESPONSABLE                ...
# SERGIO AVILA CECEÑA        ...                  58                  58
#
#                      PROVEEDOR_CONTRATISTA  RAMO  SIGLAS  SIGLAS_PAIS  \
# RESPONSABLE
# SERGIO AVILA CECEÑA                     60     0      60           60
#
#                      TIPO_CONTRATACION  TIPO_PROCEDIMIENTO  TITULO_CONTRATO  \
# RESPONSABLE
# SERGIO AVILA CECEÑA                 60                  60               60
#
#                      TITULO_EXPEDIENTE
# RESPONSABLE
# SERGIO AVILA CECEÑA                 60
#
# [1 rows x 44 columns]

# %% [markdown]
# Aquí se comprueba que la misma persona se encuentra en dos UC distintas. Esto levantaría una bandera a la UC.
